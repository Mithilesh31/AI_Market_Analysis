# %%
# EXPERIMENTAL SANDBOX

# 1. Imports
from config import *
from utils import *
import pandas as pd
import seaborn as sns

# 2. Mark as experimental
print("⚠️ NOTE: This notebook contains untested code")
print("Purpose: " + input("Describe this experiment: "))

# 3. Quick data check
df = pd.read_csv(RAW_DATA)
df.info()
# Out:
# ⚠️ NOTE: This notebook contains untested code
# Purpose:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      7000 non-null   object
#  1   product   7000 non-null   object
#  2   customer  7000 non-null   object
#  3   price     7000 non-null   float64
#  4   quantity  7000 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 273.6+ KB
